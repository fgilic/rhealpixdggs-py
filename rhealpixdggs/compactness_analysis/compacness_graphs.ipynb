# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager
import matplotlib.ticker as ticker

# %%
matplotlib.interactive(False)

# %%
nside3_res0 = pd.read_csv("compactness_res-0_nside-3.csv")
nside3_res1 = pd.read_csv("compactness_res-1_nside-3.csv")
nside3_res2 = pd.read_csv("compactness_res-2_nside-3.csv")
nside3_res3 = pd.read_csv("compactness_res-3_nside-3.csv")
nside3_res4 = pd.read_csv("compactness_res-4_nside-3.csv")
nside3_res5 = pd.read_csv("compactness_res-5_nside-3.csv")

# %%
nside3_res0.head(3)
# Out:
#    Unnamed: 0 rCell_suid rCell_region rCell_shape  Theoretical_area_of_rcell  \
# 0           0          N  north_polar         cap               8.501094e+13
# 1           1          O   equatorial        quad               8.501094e+13
# 2           2          P   equatorial        quad               8.501094e+13
#
#                                        rCell_nucleus qCell_suid  \
# 0             (np.float64(-180.0), np.float64(90.0))          N
# 1  (np.float64(-134.99999999999997), np.float64(0...          O
# 2               (np.float64(-45.0), np.float64(0.0))          P
#
#    Theoretical_area_of_qcell                qCell_nucleus  \
# 0               8.501094e+13  (-135.0, 89.99999999999999)
# 1               8.501094e+13                (-135.0, 0.0)
# 2               8.501094e+13                 (-45.0, 0.0)
#
#    Calculated_area_of_rcell  Calculated_area_of_qcell  \
# 0              8.501094e+13              8.501094e+13
# ...

# %%
plt.rcParams['axes.titlesize'] = 11
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 10
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(nrows=3, ncols=2, figsize=(16/2.54, 17.1/2.54))
nside3_res0[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax1, title="Nside=3, resolution=0", grid=True, linewidth=1.2, legend=True, color=["#A00083", "#0096A0"])
nside3_res1[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax2, title="Nside=3, resolution=1", grid=True, linewidth=1.2, legend=False, color=["#A00083", "#0096A0"])
nside3_res2[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax3, title="Nside=3, resolution=2", grid=True, linewidth=1.2, legend=False, color=["#A00083", "#0096A0"])
nside3_res3[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax4, title="Nside=3, resolution=3", grid=True, linewidth=1.2, legend=False, color=["#A00083", "#0096A0"])
nside3_res4[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax5, title="Nside=3, resolution=4", grid=True, linewidth=1.2, legend=False, color=["#A00083", "#0096A0"])
nside3_res5[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax6, title="Nside=3, resolution=5", grid=True, linewidth=1.2, legend=False, color=["#A00083", "#0096A0"])
ax1.set_ylim([0.57,1.03])
ax2.set_ylim([0.57,1.03])
ax3.set_ylim([0.57,1.03])
ax4.set_ylim([0.57,1.03])
ax5.set_ylim([0.57,1.03])
ax6.set_ylim([0.57,1.03])
ax1.set_ylabel("Compactness")
ax3.set_ylabel("Compactness")
ax5.set_ylabel("Compactness")
ax1.set_xlabel("Cell index")
ax2.set_xlabel("Cell index")
ax3.set_xlabel("Cell index")
ax4.set_xlabel("Cell index")
ax5.set_xlabel("Cell index")
ax6.set_xlabel("Cell index")
ax1.legend(["rHEALPix DGGS", "QPix DGGS"])
font_path = "../../visualizations/fonts/Oswald-Light.ttf"
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = prop.get_name()
plt.tight_layout()

# %%
fig.savefig("nside3_resolution_0-5.svg")

# %%
plt.show()

# %%
nside2_res0 = pd.read_csv("compactness_res-0_nside-2.csv")
nside2_res1 = pd.read_csv("compactness_res-1_nside-2.csv")
nside2_res2 = pd.read_csv("compactness_res-2_nside-2.csv")
nside2_res3 = pd.read_csv("compactness_res-3_nside-2.csv")
nside2_res4 = pd.read_csv("compactness_res-4_nside-2.csv")
nside2_res5 = pd.read_csv("compactness_res-5_nside-2.csv")
nside2_res6 = pd.read_csv("compactness_res-6_nside-2.csv")
nside2_res7 = pd.read_csv("compactness_res-7_nside-2.csv")
nside2_res8 = pd.read_csv("compactness_res-8_nside-2.csv")

# %%
plt.rcParams['axes.titlesize'] = 11
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 10
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(nrows=3, ncols=2, figsize=(16/2.54, 17.1/2.54))
nside2_res0[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax1, title="Nside = 2, resolution = 0", grid=True, linewidth=1.2, legend=False, color=["#A00083", "#0096A0"])
nside2_res1[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax2, title="Nside = 2, resolution = 1", grid=True, linewidth=1.2, legend=True, color=["#A00083", "#0096A0"])
nside2_res2[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax3, title="Nside = 2, resolution = 2", grid=True, linewidth=1.2, legend=False, color=["#A00083", "#0096A0"])
nside2_res3[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax4, title="Nside = 2, resolution = 3", grid=True, linewidth=1.2, legend=False, color=["#A00083", "#0096A0"])
nside2_res4[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax5, title="Nside = 2, resolution = 4", grid=True, linewidth=1.2, legend=False, color=["#A00083", "#0096A0"])
nside2_res5[["rCell_c_sp","qCell_c_sp"]].plot(ax=ax6, title="Nside = 2, resolution = 5", grid=True, linewidth=1.2, legend=False, color=["#A00083", "#0096A0"])
ax1.set_ylim([0.57,1.03])
ax2.set_ylim([0.57,1.03])
ax3.set_ylim([0.57,1.03])
ax4.set_ylim([0.57,1.03])
ax5.set_ylim([0.57,1.03])
ax6.set_ylim([0.57,1.03])
ax1.set_ylabel("Compactness")
ax3.set_ylabel("Compactness")
ax5.set_ylabel("Compactness")
ax1.set_xlabel("Cell index")
ax2.set_xlabel("Cell index")
ax3.set_xlabel("Cell index")
ax4.set_xlabel("Cell index")
ax5.set_xlabel("Cell index")
ax6.set_xlabel("Cell index")
ax2.legend(["rHEALPix DGGS", "QPix DGGS"])
font_path = "../../visualizations/fonts/Oswald-Light.ttf"
font_manager.fontManager.addfont(font_path)
prop = font_manager.FontProperties(fname=font_path)
plt.rcParams["font.family"] = "sans-serif"
plt.rcParams["font.sans-serif"] = prop.get_name()
plt.tight_layout()

# %%
fig.savefig("nside2_resolution_0-5.svg")

# %%
plt.show()

# %%
range_0_r = nside3_res0["rCell_c_sp"].max() - nside3_res0["rCell_c_sp"].min()
stdev_0_r = nside3_res0["rCell_c_sp"].std(ddof=0)
range_0_q = nside3_res0["qCell_c_sp"].max() - nside3_res0["qCell_c_sp"].min()
stdev_0_q = nside3_res0["qCell_c_sp"].std(ddof=0)

mask_1_r = nside3_res1["rCell_c_sp"] < 0.85
nside3_res1_filtered_r = nside3_res1[mask_1_r]
range_1_r = nside3_res1_filtered_r["rCell_c_sp"].max() - nside3_res1_filtered_r["rCell_c_sp"].min()
stdev_1_r = nside3_res1_filtered_r["rCell_c_sp"].std(ddof=0)
mask_1_q = nside3_res1["qCell_c_sp"] < 0.85
nside3_res1_filtered_q = nside3_res1[mask_1_q]
range_1_q = nside3_res1_filtered_q["qCell_c_sp"].max() - nside3_res1_filtered_q["qCell_c_sp"].min()
stdev_1_q = nside3_res1_filtered_q["qCell_c_sp"].std(ddof=0)

mask_2_r = nside3_res2["rCell_c_sp"] < 0.85
nside3_res2_filtered_r = nside3_res2[mask_2_r]
range_2_r = nside3_res2_filtered_r["rCell_c_sp"].max() - nside3_res2_filtered_r["rCell_c_sp"].min()
stdev_2_r = nside3_res2_filtered_r["rCell_c_sp"].std(ddof=0)
mask_2_q = nside3_res2["qCell_c_sp"] < 0.85
nside3_res2_filtered_q = nside3_res2[mask_2_q]
range_2_q = nside3_res2_filtered_q["qCell_c_sp"].max() - nside3_res2_filtered_q["qCell_c_sp"].min()
stdev_2_q = nside3_res2_filtered_q["qCell_c_sp"].std(ddof=0)

mask_3_r = nside3_res3["rCell_c_sp"] < 0.85
nside3_res3_filtered_r = nside3_res3[mask_3_r]
range_3_r = nside3_res3_filtered_r["rCell_c_sp"].max() - nside3_res3_filtered_r["rCell_c_sp"].min()
stdev_3_r = nside3_res3_filtered_r["rCell_c_sp"].std(ddof=0)
mask_3_q = nside3_res3["qCell_c_sp"] < 0.85
nside3_res3_filtered_q = nside3_res3[mask_3_q]
range_3_q = nside3_res3_filtered_q["qCell_c_sp"].max() - nside3_res3_filtered_q["qCell_c_sp"].min()
stdev_3_q = nside3_res3_filtered_q["qCell_c_sp"].std(ddof=0)

mask_4_r = nside3_res4["rCell_c_sp"] < 0.85
nside3_res4_filtered_r = nside3_res4[mask_4_r]
range_4_r = nside3_res4_filtered_r["rCell_c_sp"].max() - nside3_res4_filtered_r["rCell_c_sp"].min()
stdev_4_r = nside3_res4_filtered_r["rCell_c_sp"].std(ddof=0)
mask_4_q = nside3_res4["qCell_c_sp"] < 0.85
nside3_res4_filtered_q = nside3_res4[mask_4_q]
range_4_q = nside3_res4_filtered_q["qCell_c_sp"].max() - nside3_res4_filtered_q["qCell_c_sp"].min()
stdev_4_q = nside3_res4_filtered_q["qCell_c_sp"].std(ddof=0)

mask_5_r = nside3_res5["rCell_c_sp"] < 0.85
nside3_res5_filtered_r = nside3_res5[mask_5_r]
range_5_r = nside3_res5_filtered_r["rCell_c_sp"].max() - nside3_res5_filtered_r["rCell_c_sp"].min()
stdev_5_r = nside3_res5_filtered_r["rCell_c_sp"].std(ddof=0)
mask_5_q = nside3_res5["qCell_c_sp"] < 0.85
nside3_res5_filtered_q = nside3_res5[mask_5_q]
range_5_q = nside3_res5_filtered_q["qCell_c_sp"].max() - nside3_res5_filtered_q["qCell_c_sp"].min()
stdev_5_q = nside3_res5_filtered_q["qCell_c_sp"].std(ddof=0)

stat_dict_nside3 = {
    "resolution": [0, 1, 2, 3, 4, 5],
    "range_r": [range_0_r, range_1_r, range_2_r, range_3_r, range_4_r, range_5_r],
    "range_q": [range_0_q, range_1_q, range_2_q, range_3_q, range_4_q, range_5_q],
    "stdev_r": [stdev_0_r, stdev_1_r, stdev_2_r, stdev_3_r, stdev_4_r, stdev_5_r],
    "stdev_q": [stdev_0_q, stdev_1_q, stdev_2_q, stdev_3_q, stdev_4_q, stdev_5_q]
}

df_stat_nside3 = pd.DataFrame(stat_dict_nside3)
df_stat_nside3.set_index("resolution")

plt.rcParams['axes.titlesize'] = 11
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 10
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16/2.54, 6.7/2.54))
df_stat_nside3[["range_r", "range_q"]].plot(ax=ax1, grid=True, title="Nside = 3", linewidth=1.2, use_index=True, legend=False, style="s-", ms=4, mfc = 'w', color=["#A00083", "#0096A0"])
df_stat_nside3[["stdev_r", "stdev_q"]].plot(ax=ax2, grid=True, title="Nside = 3", linewidth=1.2, use_index=True, style="s-", ms=4, mfc = 'w', color=["#A00083", "#0096A0"])
ax1.set_xlabel("Resolution")
ax2.set_xlabel("Resolution")
ax1.set_ylabel("Compactness range")
ax2.set_ylabel("Compactness standard deviation")
ax2.legend(["rHEALPix DGGS", "QPix DGGS"])
# fig.suptitle("Nside = 3")
plt.tight_layout()

# %%
fig.savefig("nside3_range_stdev.svg")

# %%
plt.show()

# %%
range_0_r = nside2_res0["rCell_c_sp"].max() - nside2_res0["rCell_c_sp"].min()
stdev_0_r = nside2_res0["rCell_c_sp"].std(ddof=0)
range_0_q = nside2_res0["qCell_c_sp"].max() - nside2_res0["qCell_c_sp"].min()
stdev_0_q = nside2_res0["qCell_c_sp"].std(ddof=0)

range_1_r = nside2_res1["rCell_c_sp"].max() - nside2_res1["rCell_c_sp"].min()
stdev_1_r = nside2_res1["rCell_c_sp"].std(ddof=0)
range_1_q = nside2_res1["qCell_c_sp"].max() - nside2_res1["qCell_c_sp"].min()
stdev_1_q = nside2_res1["qCell_c_sp"].std(ddof=0)

range_2_r = nside2_res2["rCell_c_sp"].max() - nside2_res2["rCell_c_sp"].min()
stdev_2_r = nside2_res2["rCell_c_sp"].std(ddof=0)
range_2_q = nside2_res2["qCell_c_sp"].max() - nside2_res2["qCell_c_sp"].min()
stdev_2_q = nside2_res2["qCell_c_sp"].std(ddof=0)

range_3_r = nside2_res3["rCell_c_sp"].max() - nside2_res3["rCell_c_sp"].min()
stdev_3_r = nside2_res3["rCell_c_sp"].std(ddof=0)
range_3_q = nside2_res3["qCell_c_sp"].max() - nside2_res3["qCell_c_sp"].min()
stdev_3_q = nside2_res3["qCell_c_sp"].std(ddof=0)

range_4_r = nside2_res4["rCell_c_sp"].max() - nside2_res4["rCell_c_sp"].min()
stdev_4_r = nside2_res4["rCell_c_sp"].std(ddof=0)
range_4_q = nside2_res4["qCell_c_sp"].max() - nside2_res4["qCell_c_sp"].min()
stdev_4_q = nside2_res4["qCell_c_sp"].std(ddof=0)

range_5_r = nside2_res5["rCell_c_sp"].max() - nside2_res5["rCell_c_sp"].min()
stdev_5_r = nside2_res5["rCell_c_sp"].std(ddof=0)
range_5_q = nside2_res5["qCell_c_sp"].max() - nside2_res5["qCell_c_sp"].min()
stdev_5_q = nside2_res5["qCell_c_sp"].std(ddof=0)

range_6_r = nside2_res6["rCell_c_sp"].max() - nside2_res6["rCell_c_sp"].min()
stdev_6_r = nside2_res6["rCell_c_sp"].std(ddof=0)
range_6_q = nside2_res6["qCell_c_sp"].max() - nside2_res6["qCell_c_sp"].min()
stdev_6_q = nside2_res6["qCell_c_sp"].std(ddof=0)

range_7_r = nside2_res7["rCell_c_sp"].max() - nside2_res7["rCell_c_sp"].min()
stdev_7_r = nside2_res7["rCell_c_sp"].std(ddof=0)
range_7_q = nside2_res7["qCell_c_sp"].max() - nside2_res7["qCell_c_sp"].min()
stdev_7_q = nside2_res7["qCell_c_sp"].std(ddof=0)

range_8_r = nside2_res8["rCell_c_sp"].max() - nside2_res8["rCell_c_sp"].min()
stdev_8_r = nside2_res8["rCell_c_sp"].std(ddof=0)
range_8_q = nside2_res8["qCell_c_sp"].max() - nside2_res8["qCell_c_sp"].min()
stdev_8_q = nside2_res8["qCell_c_sp"].std(ddof=0)

stat_dict_nside3 = {
    "resolution": [0, 1, 2, 3, 4, 5, 6, 7, 8],
    "range_r": [range_0_r, range_1_r, range_2_r, range_3_r, range_4_r, range_5_r, range_6_r, range_7_r, range_8_r],
    "range_q": [range_0_q, range_1_q, range_2_q, range_3_q, range_4_q, range_5_q, range_6_q, range_7_q, range_8_q],
    "stdev_r": [stdev_0_r, stdev_1_r, stdev_2_r, stdev_3_r, stdev_4_r, stdev_5_r, stdev_6_r, stdev_7_r, stdev_8_r],
    "stdev_q": [stdev_0_q, stdev_1_q, stdev_2_q, stdev_3_q, stdev_4_q, stdev_5_q, stdev_6_q, stdev_7_q, stdev_8_q]
}

df_stat_nside3 = pd.DataFrame(stat_dict_nside3)
df_stat_nside3.set_index("resolution")

plt.rcParams['axes.titlesize'] = 11
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 10
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16/2.54, 6.7/2.54))
df_stat_nside3[["range_r", "range_q"]].plot(ax=ax1, grid=True, linewidth=1.2, use_index=True, title="Nside = 2", legend=False, style="s-", ms=4, mfc = 'w', color=["#A00083", "#0096A0"])
df_stat_nside3[["stdev_r", "stdev_q"]].plot(ax=ax2, grid=True, linewidth=1.2, use_index=True, title="Nside = 2", style="s-", ms=4, mfc = 'w', color=["#A00083", "#0096A0"])
ax1.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax2.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax1.set_xlabel("Resolution")
ax2.set_xlabel("Resolution")
ax1.set_ylabel("Compactness range")
ax2.set_ylabel("Compactness standard deviation")
ax2.legend(["rHEALPix DGGS", "QPix DGGS"])
# fig.suptitle("Nside = 2")
plt.tight_layout()

# %%
fig.savefig("nside2_range_stdev.svg")

# %%
plt.show()

# %%
range_0_r3 = nside3_res0["rCell_c_sp"].max() - nside3_res0["rCell_c_sp"].min()
range_0_q3 = nside3_res0["qCell_c_sp"].max() - nside3_res0["qCell_c_sp"].min()
range_0_r2 = nside2_res0["rCell_c_sp"].max() - nside2_res0["rCell_c_sp"].min()
range_0_q2 = nside2_res0["qCell_c_sp"].max() - nside2_res0["qCell_c_sp"].min()


mask_1_r3 = nside3_res1["rCell_c_sp"] < 0.85
nside3_res1_filtered_r3 = nside3_res1[mask_1_r3]
range_1_r3 = nside3_res1_filtered_r3["rCell_c_sp"].max() - nside3_res1_filtered_r3["rCell_c_sp"].min()
mask_1_q3 = nside3_res1["qCell_c_sp"] < 0.85
nside3_res1_filtered_q3 = nside3_res1[mask_1_q3]
range_1_q3 = nside3_res1_filtered_q3["qCell_c_sp"].max() - nside3_res1_filtered_q3["qCell_c_sp"].min()
range_1_r2 = nside2_res1["rCell_c_sp"].max() - nside2_res1["rCell_c_sp"].min()
range_1_q2 = nside2_res1["qCell_c_sp"].max() - nside2_res1["qCell_c_sp"].min()

mask_2_r3 = nside3_res2["rCell_c_sp"] < 0.85
nside3_res2_filtered_r3 = nside3_res2[mask_2_r3]
range_2_r3 = nside3_res2_filtered_r3["rCell_c_sp"].max() - nside3_res2_filtered_r3["rCell_c_sp"].min()
mask_2_q3 = nside3_res2["qCell_c_sp"] < 0.85
nside3_res2_filtered_q3 = nside3_res2[mask_2_q3]
range_2_q3 = nside3_res2_filtered_q3["qCell_c_sp"].max() - nside3_res2_filtered_q3["qCell_c_sp"].min()
range_2_r2 = nside2_res2["rCell_c_sp"].max() - nside2_res2["rCell_c_sp"].min()
range_2_q2 = nside2_res2["qCell_c_sp"].max() - nside2_res2["qCell_c_sp"].min()

mask_3_r3 = nside3_res3["rCell_c_sp"] < 0.85
nside3_res3_filtered_r3 = nside3_res3[mask_3_r3]
range_3_r3 = nside3_res3_filtered_r3["rCell_c_sp"].max() - nside3_res3_filtered_r3["rCell_c_sp"].min()
mask_3_q3 = nside3_res3["qCell_c_sp"] < 0.85
nside3_res3_filtered_q3 = nside3_res3[mask_3_q3]
range_3_q3 = nside3_res3_filtered_q3["qCell_c_sp"].max() - nside3_res3_filtered_q3["qCell_c_sp"].min()
range_3_r2 = nside2_res3["rCell_c_sp"].max() - nside2_res3["rCell_c_sp"].min()
range_3_q2 = nside2_res3["qCell_c_sp"].max() - nside2_res3["qCell_c_sp"].min()

mask_4_r3 = nside3_res4["rCell_c_sp"] < 0.85
nside3_res4_filtered_r3 = nside3_res4[mask_4_r3]
range_4_r3 = nside3_res4_filtered_r3["rCell_c_sp"].max() - nside3_res4_filtered_r3["rCell_c_sp"].min()
mask_4_q3 = nside3_res4["qCell_c_sp"] < 0.85
nside3_res4_filtered_q3 = nside3_res4[mask_4_q3]
range_4_q3 = nside3_res4_filtered_q3["qCell_c_sp"].max() - nside3_res4_filtered_q3["qCell_c_sp"].min()
range_4_r2 = nside2_res4["rCell_c_sp"].max() - nside2_res4["rCell_c_sp"].min()
range_4_q2 = nside2_res4["qCell_c_sp"].max() - nside2_res4["qCell_c_sp"].min()

mask_5_r3 = nside3_res5["rCell_c_sp"] < 0.85
nside3_res5_filtered_r3 = nside3_res5[mask_5_r3]
range_5_r3 = nside3_res5_filtered_r3["rCell_c_sp"].max() - nside3_res5_filtered_r3["rCell_c_sp"].min()
mask_5_q3 = nside3_res5["qCell_c_sp"] < 0.85
nside3_res5_filtered_q3 = nside3_res5[mask_5_q3]
range_5_q3 = nside3_res5_filtered_q3["qCell_c_sp"].max() - nside3_res5_filtered_q3["qCell_c_sp"].min()
range_5_r2 = nside2_res5["rCell_c_sp"].max() - nside2_res5["rCell_c_sp"].min()
range_5_q2 = nside2_res5["qCell_c_sp"].max() - nside2_res5["qCell_c_sp"].min()

range_6_r2 = nside2_res6["rCell_c_sp"].max() - nside2_res6["rCell_c_sp"].min()
range_6_q2 = nside2_res6["qCell_c_sp"].max() - nside2_res6["qCell_c_sp"].min()
range_7_r2 = nside2_res7["rCell_c_sp"].max() - nside2_res7["rCell_c_sp"].min()
range_7_q2 = nside2_res7["qCell_c_sp"].max() - nside2_res7["qCell_c_sp"].min()
range_8_r2 = nside2_res8["rCell_c_sp"].max() - nside2_res8["rCell_c_sp"].min()
range_8_q2 = nside2_res8["qCell_c_sp"].max() - nside2_res8["qCell_c_sp"].min()

stat_dict_nside3 = {
    "resolution": [0, 1, 2, 3, 4, 5],
    "range_r3": [range_0_r3, range_1_r3, range_2_r3, range_3_r3, range_4_r3, range_5_r3],
    "range_q3": [range_0_q3, range_1_q3, range_2_q3, range_3_q3, range_4_q3, range_5_q3]
}

stat_dict_nside2 = {
    "resolution": [0, 1, 2, 3, 4, 5, 6, 7, 8],
    "range_r2": [range_0_r2, range_1_r2, range_2_r2, range_3_r2, range_4_r2, range_5_r2, range_6_r2, range_7_r2, range_8_r2],
    "range_q2": [range_0_q2, range_1_q2, range_2_q2, range_3_q2, range_4_q2, range_5_q2, range_6_q2, range_7_q2, range_8_q2]
}

df_stat_nside3 = pd.DataFrame(stat_dict_nside3)
df_stat_nside3.set_index("resolution")
df_stat_nside2 = pd.DataFrame(stat_dict_nside2)
df_stat_nside2.set_index("resolution")

plt.rcParams['axes.titlesize'] = 11
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 10
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16/2.54, 6.7/2.54))
df_stat_nside2[["range_r2", "range_q2"]].plot(ax=ax1, grid=True, title="Nside = 2", linewidth=1.2, use_index=True, legend=False, style="s-", ms=4, mfc = 'w', color=["#A00083", "#0096A0"])
df_stat_nside3[["range_r3", "range_q3"]].plot(ax=ax2, grid=True, title="Nside = 3", linewidth=1.2, use_index=True, style="s-", ms=4, mfc = 'w', color=["#A00083", "#0096A0"])
ax1.set_xlabel("Resolution")
ax2.set_xlabel("Resolution")
ax1.set_ylabel("Compactness range")
ax2.set_ylabel("Compactness range")
ax2.legend(["rHEALPix DGGS", "QPix DGGS"])
# fig.suptitle("Nside = 3")
plt.tight_layout()

# %%
fig.savefig("range.svg")
plt.show()

# %%
range_0_r3 = nside3_res0["rCell_c_sp"].std(ddof=0)
range_0_q3 = nside3_res0["qCell_c_sp"].std(ddof=0)
range_0_r2 = nside2_res0["rCell_c_sp"].std(ddof=0)
range_0_q2 = nside2_res0["qCell_c_sp"].std(ddof=0)

mask_1_r3 = nside3_res1["rCell_c_sp"] < 0.85
nside3_res1_filtered_r3 = nside3_res1[mask_1_r3]
range_1_r3 = nside3_res1_filtered_r3["rCell_c_sp"].std(ddof=0)
mask_1_q3 = nside3_res1["qCell_c_sp"] < 0.85
nside3_res1_filtered_q3 = nside3_res1[mask_1_q3]
range_1_q3 = nside3_res1_filtered_q3["qCell_c_sp"].std(ddof=0)
range_1_r2 = nside2_res1["rCell_c_sp"].std(ddof=0)
range_1_q2 = nside2_res1["qCell_c_sp"].std(ddof=0)

mask_2_r3 = nside3_res2["rCell_c_sp"] < 0.85
nside3_res2_filtered_r3 = nside3_res2[mask_2_r3]
range_2_r3 = nside3_res2_filtered_r3["rCell_c_sp"].std(ddof=0)
mask_2_q3 = nside3_res2["qCell_c_sp"] < 0.85
nside3_res2_filtered_q3 = nside3_res2[mask_2_q3]
range_2_q3 = nside3_res2_filtered_q3["qCell_c_sp"].std(ddof=0)
range_2_r2 = nside2_res2["rCell_c_sp"].std(ddof=0)
range_2_q2 = nside2_res2["qCell_c_sp"].std(ddof=0)

mask_3_r3 = nside3_res3["rCell_c_sp"] < 0.85
nside3_res3_filtered_r3 = nside3_res3[mask_3_r3]
range_3_r3 = nside3_res3_filtered_r3["rCell_c_sp"].std(ddof=0)
mask_3_q3 = nside3_res3["qCell_c_sp"] < 0.85
nside3_res3_filtered_q3 = nside3_res3[mask_3_q3]
range_3_q3 = nside3_res3_filtered_q3["qCell_c_sp"].std(ddof=0)
range_3_r2 = nside2_res3["rCell_c_sp"].std(ddof=0)
range_3_q2 = nside2_res3["qCell_c_sp"].std(ddof=0)

mask_4_r3 = nside3_res4["rCell_c_sp"] < 0.85
nside3_res4_filtered_r3 = nside3_res4[mask_4_r3]
range_4_r3 = nside3_res4_filtered_r3["rCell_c_sp"].std(ddof=0)
mask_4_q3 = nside3_res4["qCell_c_sp"] < 0.85
nside3_res4_filtered_q3 = nside3_res4[mask_4_q3]
range_4_q3 = nside3_res4_filtered_q3["qCell_c_sp"].std(ddof=0)
range_4_r2 = nside2_res4["rCell_c_sp"].std(ddof=0)
range_4_q2 = nside2_res4["qCell_c_sp"].std(ddof=0)

mask_5_r3 = nside3_res5["rCell_c_sp"] < 0.85
nside3_res5_filtered_r3 = nside3_res5[mask_5_r3]
range_5_r3 = nside3_res5_filtered_r3["rCell_c_sp"].std(ddof=0)
mask_5_q3 = nside3_res5["qCell_c_sp"] < 0.85
nside3_res5_filtered_q3 = nside3_res5[mask_5_q3]
range_5_q3 = nside3_res5_filtered_q3["qCell_c_sp"].std(ddof=0)
range_5_r2 = nside2_res5["rCell_c_sp"].std(ddof=0)
range_5_q2 = nside2_res5["qCell_c_sp"].std(ddof=0)

range_6_r2 = nside2_res6["rCell_c_sp"].std(ddof=0)
range_6_q2 = nside2_res6["qCell_c_sp"].std(ddof=0)
range_7_r2 = nside2_res7["rCell_c_sp"].std(ddof=0)
range_7_q2 = nside2_res7["qCell_c_sp"].std(ddof=0)
range_8_r2 = nside2_res8["rCell_c_sp"].std(ddof=0)
range_8_q2 = nside2_res8["qCell_c_sp"].std(ddof=0)

stat_dict_nside3 = {
    "resolution": [0, 1, 2, 3, 4, 5],
    "range_r3": [range_0_r3, range_1_r3, range_2_r3, range_3_r3, range_4_r3, range_5_r3],
    "range_q3": [range_0_q3, range_1_q3, range_2_q3, range_3_q3, range_4_q3, range_5_q3]
}

stat_dict_nside2 = {
    "resolution": [0, 1, 2, 3, 4, 5, 6, 7, 8],
    "range_r2": [range_0_r2, range_1_r2, range_2_r2, range_3_r2, range_4_r2, range_5_r2, range_6_r2, range_7_r2, range_8_r2],
    "range_q2": [range_0_q2, range_1_q2, range_2_q2, range_3_q2, range_4_q2, range_5_q2, range_6_q2, range_7_q2, range_8_q2]
}

df_stat_nside3 = pd.DataFrame(stat_dict_nside3)
df_stat_nside3.set_index("resolution")
df_stat_nside2 = pd.DataFrame(stat_dict_nside2)
df_stat_nside2.set_index("resolution")

plt.rcParams['axes.titlesize'] = 11
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 10
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16/2.54, 6.7/2.54))
df_stat_nside2[["range_r2", "range_q2"]].plot(ax=ax1, grid=True, title="Nside = 2", linewidth=1.2, use_index=True, legend=False, style="s-", ms=4, mfc = 'w', color=["#A00083", "#0096A0"])
df_stat_nside3[["range_r3", "range_q3"]].plot(ax=ax2, grid=True, title="Nside = 3", linewidth=1.2, use_index=True, style="s-", ms=4, mfc = 'w', color=["#A00083", "#0096A0"])
ax1.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax2.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax1.set_xlabel("Resolution")
ax2.set_xlabel("Resolution")
ax1.set_ylabel("Compactness standar deviation")
ax2.set_ylabel("Compactness standar deviation")
ax2.legend(["rHEALPix DGGS", "QPix DGGS"])
# fig.suptitle("Nside = 3")
plt.tight_layout()

# %%
fig.savefig("stdev.svg")
plt.show()

# %%
range_0_r3 = nside3_res0["rCell_c_sp"].mean()
range_0_q3 = nside3_res0["qCell_c_sp"].mean()
range_0_r2 = nside2_res0["rCell_c_sp"].mean()
range_0_q2 = nside2_res0["qCell_c_sp"].mean()

mask_1_r3 = nside3_res1["rCell_c_sp"] < 0.85
nside3_res1_filtered_r3 = nside3_res1[mask_1_r3]
range_1_r3 = nside3_res1_filtered_r3["rCell_c_sp"].mean()
mask_1_q3 = nside3_res1["qCell_c_sp"] < 0.85
nside3_res1_filtered_q3 = nside3_res1[mask_1_q3]
range_1_q3 = nside3_res1_filtered_q3["qCell_c_sp"].mean()
range_1_r2 = nside2_res1["rCell_c_sp"].mean()
range_1_q2 = nside2_res1["qCell_c_sp"].mean()

mask_2_r3 = nside3_res2["rCell_c_sp"] < 0.85
nside3_res2_filtered_r3 = nside3_res2[mask_2_r3]
range_2_r3 = nside3_res2_filtered_r3["rCell_c_sp"].mean()
mask_2_q3 = nside3_res2["qCell_c_sp"] < 0.85
nside3_res2_filtered_q3 = nside3_res2[mask_2_q3]
range_2_q3 = nside3_res2_filtered_q3["qCell_c_sp"].mean()
range_2_r2 = nside2_res2["rCell_c_sp"].mean()
range_2_q2 = nside2_res2["qCell_c_sp"].mean()

mask_3_r3 = nside3_res3["rCell_c_sp"] < 0.85
nside3_res3_filtered_r3 = nside3_res3[mask_3_r3]
range_3_r3 = nside3_res3_filtered_r3["rCell_c_sp"].mean()
mask_3_q3 = nside3_res3["qCell_c_sp"] < 0.85
nside3_res3_filtered_q3 = nside3_res3[mask_3_q3]
range_3_q3 = nside3_res3_filtered_q3["qCell_c_sp"].mean()
range_3_r2 = nside2_res3["rCell_c_sp"].mean()
range_3_q2 = nside2_res3["qCell_c_sp"].mean()

mask_4_r3 = nside3_res4["rCell_c_sp"] < 0.85
nside3_res4_filtered_r3 = nside3_res4[mask_4_r3]
range_4_r3 = nside3_res4_filtered_r3["rCell_c_sp"].mean()
mask_4_q3 = nside3_res4["qCell_c_sp"] < 0.85
nside3_res4_filtered_q3 = nside3_res4[mask_4_q3]
range_4_q3 = nside3_res4_filtered_q3["qCell_c_sp"].mean()
range_4_r2 = nside2_res4["rCell_c_sp"].mean()
range_4_q2 = nside2_res4["qCell_c_sp"].mean()

mask_5_r3 = nside3_res5["rCell_c_sp"] < 0.85
nside3_res5_filtered_r3 = nside3_res5[mask_5_r3]
range_5_r3 = nside3_res5_filtered_r3["rCell_c_sp"].mean()
mask_5_q3 = nside3_res5["qCell_c_sp"] < 0.85
nside3_res5_filtered_q3 = nside3_res5[mask_5_q3]
range_5_q3 = nside3_res5_filtered_q3["qCell_c_sp"].mean()
range_5_r2 = nside2_res5["rCell_c_sp"].mean()
range_5_q2 = nside2_res5["qCell_c_sp"].mean()

range_6_r2 = nside2_res6["rCell_c_sp"].mean()
range_6_q2 = nside2_res6["qCell_c_sp"].mean()
range_7_r2 = nside2_res7["rCell_c_sp"].mean()
range_7_q2 = nside2_res7["qCell_c_sp"].mean()
range_8_r2 = nside2_res8["rCell_c_sp"].mean()
range_8_q2 = nside2_res8["qCell_c_sp"].mean()

stat_dict_nside3 = {
    "resolution": [0, 1, 2, 3, 4, 5],
    "range_r3": [range_0_r3, range_1_r3, range_2_r3, range_3_r3, range_4_r3, range_5_r3],
    "range_q3": [range_0_q3, range_1_q3, range_2_q3, range_3_q3, range_4_q3, range_5_q3]
}

stat_dict_nside2 = {
    "resolution": [0, 1, 2, 3, 4, 5, 6, 7, 8],
    "range_r2": [range_0_r2, range_1_r2, range_2_r2, range_3_r2, range_4_r2, range_5_r2, range_6_r2, range_7_r2, range_8_r2],
    "range_q2": [range_0_q2, range_1_q2, range_2_q2, range_3_q2, range_4_q2, range_5_q2, range_6_q2, range_7_q2, range_8_q2]
}

df_stat_nside3 = pd.DataFrame(stat_dict_nside3)
df_stat_nside3.set_index("resolution")
df_stat_nside2 = pd.DataFrame(stat_dict_nside2)
df_stat_nside2.set_index("resolution")

plt.rcParams['axes.titlesize'] = 11
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['legend.fontsize'] = 10
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16/2.54, 6.7/2.54))
df_stat_nside2[["range_r2", "range_q2"]].plot(ax=ax1, grid=True, title="Nside = 2", linewidth=1.2, use_index=True, legend=False, style="s-", ms=4, mfc = 'w', color=["#A00083", "#0096A0"])
df_stat_nside3[["range_r3", "range_q3"]].plot(ax=ax2, grid=True, title="Nside = 3", linewidth=1.2, use_index=True, style="s-", ms=4, mfc = 'w', color=["#A00083", "#0096A0"])
ax1.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax2.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax1.set_xlabel("Resolution")
ax2.set_xlabel("Resolution")
ax1.set_ylabel("Mean compactness")
ax2.set_ylabel("Mean compactness")
ax2.legend(["rHEALPix DGGS", "QPix DGGS"])
# fig.suptitle("Nside = 3")
plt.tight_layout()

# %%
fig.savefig("mean.svg")
plt.show()
